# %%
secret = 7
guess = 4

if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')
# Out:
# too low

# %%
small = True
green = False

if small and green:
    print('pea')
elif small and not green:
    print('cherry')
elif not small and green:
    print('watermelon')
else:
    print('pumpkin')
# Out:
# cherry

# %%
for value in [3, 2, 1, 0]:
    print(value)
# Out:
# 3
# 2
# 1
# 0

# %%
guess_me = 7
number = 1

while True:
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    else:
        print('oops')
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!
